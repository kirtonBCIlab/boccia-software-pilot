# %%
## Import modules
import sys
import mne
import pyxdf
import numpy as np
import pandas as pd

## Import custom modules
sys.path.append("..") # Adds higher directory to python modules path.
from Functions import import_data
from Functions import data_tools

# %% [markdown]
# ## File to read

# %%
file = "..\\Data\\sub-P002\\ses-S003\\eeg\\sub-P002_ses-S003_task-T1_run-001_eeg.xdf"
# file = "..\\Data\\sub-P001\\ses-S001\\eeg\\sub-P001_ses-S001_task-T1_run-001_eeg.xdf"

# %% [markdown]
# ## Import data
#
# Import data and marker streams. Then create epochs based on `python_stream` markers

# %%
[eeg_mne, python_stream, unity_stream] = data_tools.import_data(file)
# Out:
# Creating RawArray with float64 data, n_channels=23, n_times=131103
#     Range : 0 ... 131102 =      0.000 ...   437.007 secs
# Ready.

# %%
# Missing implementation
data_tools.create_epochs(eeg_mne, python_stream, time=[0,0], events=["ssvep"])
# Out:
# 0

# %% [markdown]
# ## Import raw data

# %% [markdown]
# ## MNE
#
# Create MNE object and visualize

# %%
# %matplotlib qt

eeg_mne.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1920x1057 with 4 Axes>
# Channels marked as bad:
# none
