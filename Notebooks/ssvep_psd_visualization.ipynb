# %%
## Import modules
import sys
import mne
import numpy as np
import pyxdf
# import pandas as pd

## Import custom modules
sys.path.append("..") # Adds higher directory to python modules path.
from Functions import import_data

# %% [markdown]
# ## File to read

# %%
file = "..\\Data\\sub-P002\\ses-S003\\eeg\\sub-P002_ses-S003_task-T1_run-001_eeg.xdf"

# %% [markdown]
# ## Import data and markers

# %%
[xdf_file, _] = pyxdf.load_xdf(file)

for i in range(len(xdf_file)):
    stream_name = xdf_file[i]["info"]["name"][0]

    # Data stream
    if (stream_name == "DSI24") | (stream_name == "DSI7"):
        eeg_np = xdf_file[i]["time_series"]
        srate = float(xdf_file[i]["info"]["nominal_srate"][0])
        n_chans = len(xdf_file[i]['info']['desc'][0]['channels'][0]['channel'])
        ch_names = [xdf_file[i]['info']['desc'][0]['channels'][0]['channel'][i]['label'][0] for c in range(n_chans)]
        eeg_time_stamps = xdf_file[i]["time_stamps"]

    # Unity stream
    if (stream_name == "PythonResponse"):
        stim_series = xdf_file[i]["time_series"]
        stim_time_stamps = xdf_file[i]["time_stamps"]

# %%
xdf_file[2]["time_series"]
# Out:
# [['Starting Experiment: 239.7174'],
#  ['Starting Experiment: 239.7174'],
#  ['041, Correctly chose going to Rotation View! Time since experiment start: 13.87492'],
#  ['442, Wrongly chose to rotate left (s). Time since experiment start: 25.03217'],
#  ['541, Correctly rotated right (s)! Time since experiment start: 36.2142'],
#  ['442, Wrongly chose to rotate left (s). Time since experiment start: 47.65045'],
#  ['442, Wrongly chose to rotate left (s). Time since experiment start: 58.88113'],
#  ['442, Wrongly chose to rotate left (s). Time since experiment start: 69.9274'],
#  ['442, Wrongly chose to rotate left (s). Time since experiment start: 81.23096'],
#  ['541, Correctly rotated right (s)! Time since experiment start: 92.54755'],
#  ['142, Wrongly chose to return to Main Menu. Time since experiment start: 103.672'],
#  ['041, Correctly chose going to Rotation View! Time since experiment start: 114.8308'],
# ...

# %% [markdown]
# ## Reshape raw data to SSVEP windows
#
# Reshape the complete RAW data to a `m * n * o * p` matrix where the dimensions are:
# - `m`: SSVEP stimulus (i.e., 8, 10, or 12 Hz)
# - `n`: SSVEP window
# - `o`: EEG samples
# - `p`:

# %%
xdf_file[0]["time_stamps"]
# Out:
# array([647985.81895799, 647985.82229129, 647985.82562459, ...,
#        648422.81486124, 648422.81819454, 648422.82152784])

# %%
info.channels = 
mne.io.RawArray(eeg_np)
# Out:
# [['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
#  ['ping'],
# ...

# %% [markdown]
# ## Import raw data

# %%
## Settings
file = "..\\Data\\sub-P002\\ses-S003\\eeg\\sub-P002_ses-S003_task-T1_run-001_eeg.xdf"

## Import data
data = import_data.read_xdf(file)

# %% [markdown]
# ## MNE
#
# Create MNE object and visualize
